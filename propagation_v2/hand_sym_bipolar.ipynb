# %%
import sys
sys.path.append('../')

import numpy as np
from scipy import ndimage

from skimage.filters import sobel_h
from skimage.filters import sobel_v
from scipy import stats


import os

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.proj3d import proj_transform
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d


import scienceplots
from tensorflow.python.client import device_lib

#plt.rcParams['figure.figsize'] = [10,10]

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import decode_predictions
from tensorflow.keras.applications import VGG16

from tensorflow.nn import depthwise_conv2d
from tensorflow.math import multiply, reduce_sum, reduce_mean,reduce_euclidean_norm, sin, cos, abs
from tensorflow import stack, concat, expand_dims

import tensorflow_probability as tfp

from utils.utils import *
import cv2

from scipy import ndimage, fft

plt.style.use(['science', 'ieee'])
plt.rcParams.update({'figure.dpi': '100'})

# %% [markdown]
# #### Experiment #1 : HandCrafted AntiSymmetric Bipolar Convolution

# %%
k = 20 # Top 10% highest l2-magnitude filters

# %%
F = 0

filters = np.zeros((3,3,2,2))
filters[:,:,0,0] =  (1/9)*np.array([[1,1,1], [1,1,1], [1,1,1]]) 
filters[:,:,1,0] =  -(1/9)*np.array([[1,1,1], [1,1,1], [1,1,1]]) 
filters[:,:,:,1] = filters[:,:,:,0]

filters = filters/10.
theta = getSobelTF(filters)
print(filters.shape)
s, a = getSymAntiSymTF(filters)

a_mag = reduce_euclidean_norm(a, axis=[0,1])
s_mag = reduce_euclidean_norm(s, axis=[0,1])
mag = reduce_euclidean_norm(filters, axis=[0,1])


x =(a_mag[:,F]*np.cos((theta[:,F]))).numpy()
y =( a_mag[:,F]*np.sin((theta[:,F]))).numpy()
z =(s_mag[:,F]*np.sign(np.mean(s, axis=(0,1)))[:,F]).numpy()
plt.rcParams.update({'figure.dpi': '100'})


class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        super().__init__((0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def do_3d_projection(self, renderer=None):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj_transform(xs3d, ys3d, zs3d, self.axes.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        return np.min(zs)

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)

# Create a new figure and a 3D axis
fig = plt.figure(figsize=(15, 15),constrained_layout=True)
ax = fig.add_subplot(111, projection='3d')

# Remove the panes (walls)
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

# Remove the pane lines
ax.xaxis.pane.set_edgecolor('none')
ax.yaxis.pane.set_edgecolor('none')
ax.zaxis.pane.set_edgecolor('none')

# Remove grid lines
ax.grid(False)

# Remove default tick marks and labels
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])

# Create the axes lines
axis_length = 10
ax.plot([-1, 1], [0, 0], [0, 0], 'k-', linewidth=2)  # x-axis
ax.plot([0, 0], [-1, 1], [0, 0], 'k-', linewidth=2)  # y-axis
ax.plot([0, 0], [0, 0], [-1, 1], 'k-', linewidth=2)  # z-axis

# Set labels for the axes
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set the limits for each axis
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(-1, 1)

arrow_prop_dict = dict(mutation_scale=20, arrowstyle='<|-|>', shrinkA=0, shrinkB=0)


    
a = Arrow3D([- 1.02, 1.02], [0, 0], [0, 0], **arrow_prop_dict, color='k')
ax.add_artist(a)
a = Arrow3D( [0, 0],[- 1.02, 1.02], [0, 0], **arrow_prop_dict, color='k')
ax.add_artist(a)
a = Arrow3D([0, 0], [0, 0],[-1.02, 1.02], **arrow_prop_dict, color='k')
ax.add_artist(a)


# Color the x,y plane
xx, yy = np.meshgrid(range(-1, 2), range(-1, 2))
ax.plot_surface(xx, yy, np.zeros_like(xx), alpha=0.2, color='blue') 
# Add text to the x,y plane
#ax.text(0, 0, 0, "X-Y Plane", fontsize=14, ha='center', va='center', 
#        zdir='x', zorder=20)# Example: Plot some 3D points
points = np.array([x,y,z]).T*3
ax.scatter(points[:, 0], points[:, 1], points[:, 2], c='k', s=200)
plt.axis('off')
# Show the plot

ax.view_init(elev=20, azim=40)

fig.savefig(f'hand_L{l_num}_f{F}_sym_bipol.pdf', dpi=600,  transparent=True, bbox_inches='tight')
plt.show()

import subprocess
subprocess.run(["pdfcrop ", f'hand_L{l_num}_f{F}_sym_bipol.pdf'])
# Out:
# (3, 3, 2, 2)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22368\57981897.py in <module>
#     102 ax.view_init(elev=20, azim=40)
#     103
# --> 104 fig.savefig(f'hand_L{l_num}_f{F}_sym_bipol.pdf', dpi=600,  transparent=True, bbox_inches='tight')
#     105 plt.show()
#     106
#
# NameError: name 'l_num' is not defined
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\ipykernel_launcher.py:37: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.

# %%
#var = 2/(128*9)

img =  cv2.imread('input4.png', 0)/255. 
#img = (img-np.mean(img))/np.std(img)
#img = tf.repeat(tf.expand_dims([img], axis=-1) , repeats = 512, axis=-1)  #get_double_slit(shape) , axis=0)
print(img.shape)
# Out:
# (224, 224)

# %%
np.var(img), 1/(128*9)
# Out:
# (0.023040123255935026, 0.0008680555555555555)

# %%
w =tf.cast(filters, dtype=tf.float32) # tf.expand_dims(filters, -1), dtype=tf.float32)
print(w.shape)

x = img


directory = f"figures/hand_sym_bipolar"
if not os.path.exists(directory):
	os.makedirs(directory)
x = tf.cast(tf.repeat(tf.expand_dims([img], axis=-1) , repeats = filters.shape[-2], axis=-1), dtype=tf.float32) 
for i in range(200):
	print(i)
	fig, ax = plt.subplots()
	x = x/np.std(x)
	x = tf.nn.relu( tf.nn.conv2d(x, w*np.random.uniform(0.9,1.1, size=(1,1,2,2)) , strides=(1,1), 
							padding='SAME') )
	
	#x = tf.repeat(x , repeats = filters.shape[-2], axis=-1)
	print(x.shape)

	im = ax.imshow(np.sum(x[0,:,:,:], axis=-1))
	ax.plot(112, 112, marker = '+', color='red')
	ax.set(xlim=(0, 224), ylim=(0, 224))

	fig.colorbar(im, orientation='vertical')
	fig.savefig(directory + f'/{i}.pdf', dpi=600,  transparent=True, bbox_inches='tight')
# Out:
# (3, 3, 2, 2)
# 0
# (1, 224, 224, 2)
# 1
# (1, 224, 224, 2)
# 2
# (1, 224, 224, 2)
# 3
# (1, 224, 224, 2)
# 4
# (1, 224, 224, 2)
# 5
# (1, 224, 224, 2)
# 6
# (1, 224, 224, 2)
# 7
# (1, 224, 224, 2)
# 8
# (1, 224, 224, 2)
# 9
# (1, 224, 224, 2)
# 10
# (1, 224, 224, 2)
# 11
# (1, 224, 224, 2)
# 12
# (1, 224, 224, 2)
# 13
# (1, 224, 224, 2)
# 14
# (1, 224, 224, 2)
# 15
# (1, 224, 224, 2)
# 16
# (1, 224, 224, 2)
# 17
# (1, 224, 224, 2)
# 18
# (1, 224, 224, 2)
# 19
# (1, 224, 224, 2)
# 20
# (1, 224, 224, 2)
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# 21
# (1, 224, 224, 2)
# 22
# (1, 224, 224, 2)
# 23
# (1, 224, 224, 2)
# 24
# (1, 224, 224, 2)
# 25
# (1, 224, 224, 2)
# 26
# (1, 224, 224, 2)
# 27
# (1, 224, 224, 2)
# 28
# (1, 224, 224, 2)
# 29
# (1, 224, 224, 2)
# 30
# (1, 224, 224, 2)
# 31
# (1, 224, 224, 2)
# 32
# (1, 224, 224, 2)
# 33
# (1, 224, 224, 2)
# 34
# (1, 224, 224, 2)
# 35
# (1, 224, 224, 2)
# 36
# (1, 224, 224, 2)
# 37
# (1, 224, 224, 2)
# 38
# (1, 224, 224, 2)
# 39
# (1, 224, 224, 2)
# 40
# (1, 224, 224, 2)
# 41
# (1, 224, 224, 2)
# 42
# (1, 224, 224, 2)
# 43
# (1, 224, 224, 2)
# 44
# (1, 224, 224, 2)
# 45
# (1, 224, 224, 2)
# 46
# (1, 224, 224, 2)
# 47
# (1, 224, 224, 2)
# 48
# (1, 224, 224, 2)
# 49
# (1, 224, 224, 2)
# 50
# (1, 224, 224, 2)
# 51
# (1, 224, 224, 2)
# 52
# (1, 224, 224, 2)
# 53
# (1, 224, 224, 2)
# 54
# (1, 224, 224, 2)
# 55
# (1, 224, 224, 2)
# 56
# (1, 224, 224, 2)
# 57
# (1, 224, 224, 2)
# 58
# (1, 224, 224, 2)
# 59
# (1, 224, 224, 2)
# 60
# (1, 224, 224, 2)
# 61
# (1, 224, 224, 2)
# 62
# (1, 224, 224, 2)
# 63
# (1, 224, 224, 2)
# 64
# (1, 224, 224, 2)
# 65
# (1, 224, 224, 2)
# 66
# (1, 224, 224, 2)
# 67
# (1, 224, 224, 2)
# 68
# (1, 224, 224, 2)
# 69
# (1, 224, 224, 2)
# 70
# (1, 224, 224, 2)
# 71
# (1, 224, 224, 2)
# 72
# (1, 224, 224, 2)
# 73
# (1, 224, 224, 2)
# 74
# (1, 224, 224, 2)
# 75
# (1, 224, 224, 2)
# 76
# (1, 224, 224, 2)
# 77
# (1, 224, 224, 2)
# 78
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22368\2551168120.py in <module>
#      11 for i in range(200):
#      12         print(i)
# ---> 13         fig, ax = plt.subplots()
#      14         x = x/np.std(x)
#      15 	x = tf.nn.relu( tf.nn.conv2d(x, w*np.random.uniform(0.9,1.1, size=(1,1,2,2)) , strides=(1,1),
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1435     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1436                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1437                        gridspec_kw=gridspec_kw)
#    1438     return fig, axs
#    1439
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#     896         gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     897         axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
# --> 898                           subplot_kw=subplot_kw)
#     899         return axs
#     900
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     306                 subplot_kw["sharey"] = shared_with[sharey]
#     307                 axarr[row, col] = figure.add_subplot(
# --> 308                     self[row, col], **subplot_kw)
#     309
#     310         # turn off redundant tick labeling
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#     770             projection_class, pkw = self._process_projection_requirements(
#     771                 *args, **kwargs)
# --> 772             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773             key = (projection_class, pkw)
#     774         return self._add_axes_internal(ax, key)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      32         """
#      33         # _axes_class is set in the subplot_class_factory
# ---> 34         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35         # This will also update the axes position.
#      36         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     622
#     623         # this call may differ for non-sep axes, e.g., polar
# --> 624         self._init_axis()
#     625         if facecolor is None:
#     626             facecolor = mpl.rcParams['axes.facecolor']
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\axes\_base.py in _init_axis(self)
#     744         self.spines.bottom.register_axis(self.xaxis)
#     745         self.spines.top.register_axis(self.xaxis)
# --> 746         self.yaxis = maxis.YAxis(self)
#     747         self.spines.left.register_axis(self.yaxis)
#     748         self.spines.right.register_axis(self.yaxis)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#    2278
#    2279     def __init__(self, *args, **kwargs):
# -> 2280         super().__init__(*args, **kwargs)
#    2281         # x in display coords, y in axes coords (to be updated at draw time by
#    2282         # _update_label_positions and _update_offset_text_position).
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\axis.py in __init__(self, axes, pickradius)
#     679
#     680         self.clear()
# --> 681         self._set_scale('linear')
#     682
#     683     @property
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\axis.py in _set_scale(self, value, **kwargs)
#     762         else:
#     763             self._scale = value
# --> 764         self._scale.set_default_locators_and_formatters(self)
#     765
#     766         self.isDefault_majloc = True
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\scale.py in set_default_locators_and_formatters(self, axis)
#     105         # docstring inherited
#     106         axis.set_major_locator(AutoLocator())
# --> 107         axis.set_major_formatter(ScalarFormatter())
#     108         axis.set_minor_formatter(NullFormatter())
#     109         # update the minor locator for x and y axis based on rcParams
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\ticker.py in __init__(self, useOffset, useMathText, useLocale)
#     446                             mpl.rcParams["font.family"]
#     447                         ),
# --> 448                         fallback_to_default=False,
#     449                     )
#     450                 except ValueError:
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\font_manager.py in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1307         return self._findfont_cached(
#    1308             prop, fontext, directory, fallback_to_default, rebuild_if_missing,
# -> 1309             rc_params)
#    1310
#    1311     @lru_cache()
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\font_manager.py in _findfont_cached(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing, rc_params)
#    1338                      + self.score_weight(prop.get_weight(), font.weight)
#    1339                      + self.score_stretch(prop.get_stretch(), font.stretch)
# -> 1340                      + self.score_size(prop.get_size(), font.size))
#    1341             _log.debug('findfont: score(%s) = %s', font, score)
#    1342             if score < best_score:
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\font_manager.py in score_family(self, families, family2)
#    1148             family1 = family1.lower()
#    1149             if family1 in font_family_aliases:
# -> 1150                 options = [*map(str.lower, self._expand_aliases(family1))]
#    1151                 if family2 in options:
#    1152                     idx = options.index(family2)
#
# c:\Users\AN46710\Anaconda3\envs\masters\lib\site-packages\matplotlib\font_manager.py in _expand_aliases(family)
#    1124         if family in ('sans', 'sans serif'):
#    1125             family = 'sans-serif'
# -> 1126         return rcParams['font.' + family]
#    1127
#    1128     # Each of the scoring functions below should return a value between
#
# KeyboardInterrupt:
